# %%
import pandas as pd
import seaborn as sns

nginx = {
    "name": "nginx",
    "ip": "nginx.antoniszczepanik.com",
}

h2o = {
    "name": "h2o",
    "ip": "h2o.antoniszczepanik.com",
}

caddy = {
    "name": "caddy",
    "ip": "caddy.antoniszczepanik.com",
}

ls = {
    "name": "openlitespeed",
    "ip": "litespeed.antoniszczepanik.com",
}

iperf_port = "6969"

servers = (nginx, h2o, caddy, ls)

# %% [markdown]
# ## Bandwidth and latency test

# %% [markdown]
# ### Latency

# %%
for server in servers:
    print("")
    print(f"==================== PING {server['name']} ==========================")
    # !ping -c 5 {server["ip"]}
# Out:
# ==================== PING nginx ==========================
# PING nginx.antoniszczepanik.com (18.159.234.10) 56(84) bytes of data.
# 64 bytes from ec2-18-159-234-10.eu-central-1.compute.amazonaws.com (18.159.234.10): icmp_seq=1 ttl=63 time=0.287 ms
# 64 bytes from ec2-18-159-234-10.eu-central-1.compute.amazonaws.com (18.159.234.10): icmp_seq=2 ttl=63 time=0.262 ms
# 64 bytes from ec2-18-159-234-10.eu-central-1.compute.amazonaws.com (18.159.234.10): icmp_seq=3 ttl=63 time=0.274 ms
# 64 bytes from ec2-18-159-234-10.eu-central-1.compute.amazonaws.com (18.159.234.10): icmp_seq=4 ttl=63 time=0.230 ms
# 64 bytes from ec2-18-159-234-10.eu-central-1.compute.amazonaws.com (18.159.234.10): icmp_seq=5 ttl=63 time=0.242 ms
#
# --- nginx.antoniszczepanik.com ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4067ms
# rtt min/avg/max/mdev = 0.230/0.259/0.287/0.020 ms
#
# ==================== PING h2o ==========================
# PING h2o.antoniszczepanik.com (3.72.136.224) 56(84) bytes of data.
# 64 bytes from ec2-3-72-136-224.eu-central-1.compute.amazonaws.com (3.72.136.224): icmp_seq=1 ttl=63 time=0.375 ms
# 64 bytes from ec2-3-72-136-224.eu-central-1.compute.amazonaws.com (3.72.136.224): icmp_seq=2 ttl=63 time=0.243 ms
# 64 bytes from ec2-3-72-136-224.eu-central-1.compute.amazonaws.com (3.72.136.224): icmp_seq=3 ttl=63 time=0.278 ms
# 64 bytes from ec2-3-72-136-224.eu-central-1.compute.amazonaws.com (3.72.136.224): icmp_seq=4 ttl=63 time=2.28 ms
# 64 bytes from ec2-3-72-136-224.eu-central-1.compute.amazonaws.com (3.72.136.224): icmp_seq=5 ttl=63 time=0.234 ms
#
# --- h2o.antoniszczepanik.com ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4044ms
# rtt min/avg/max/mdev = 0.234/0.681/2.276/0.798 ms
#
# ==================== PING caddy ==========================
# PING caddy.antoniszczepanik.com (18.158.249.152) 56(84) bytes of data.
# 64 bytes from ec2-18-158-249-152.eu-central-1.compute.amazonaws.com (18.158.249.152): icmp_seq=1 ttl=63 time=0.427 ms
# 64 bytes from ec2-18-158-249-152.eu-central-1.compute.amazonaws.com (18.158.249.152): icmp_seq=2 ttl=63 time=0.355 ms
# 64 bytes from ec2-18-158-249-152.eu-central-1.compute.amazonaws.com (18.158.249.152): icmp_seq=3 ttl=63 time=0.369 ms
# 64 bytes from ec2-18-158-249-152.eu-central-1.compute.amazonaws.com (18.158.249.152): icmp_seq=4 ttl=63 time=0.389 ms
# 64 bytes from ec2-18-158-249-152.eu-central-1.compute.amazonaws.com (18.158.249.152): icmp_seq=5 ttl=63 time=0.429 ms
#
# --- caddy.antoniszczepanik.com ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4052ms
# rtt min/avg/max/mdev = 0.355/0.393/0.429/0.029 ms
#
# ==================== PING openlitespeed ==========================
# PING litespeed.antoniszczepanik.com (3.65.201.207) 56(84) bytes of data.
# 64 bytes from ec2-3-65-201-207.eu-central-1.compute.amazonaws.com (3.65.201.207): icmp_seq=1 ttl=63 time=0.362 ms
# 64 bytes from ec2-3-65-201-207.eu-central-1.compute.amazonaws.com (3.65.201.207): icmp_seq=2 ttl=63 time=0.413 ms
# 64 bytes from ec2-3-65-201-207.eu-central-1.compute.amazonaws.com (3.65.201.207): icmp_seq=3 ttl=63 time=0.349 ms
# 64 bytes from ec2-3-65-201-207.eu-central-1.compute.amazonaws.com (3.65.201.207): icmp_seq=4 ttl=63 time=0.357 ms
# 64 bytes from ec2-3-65-201-207.eu-central-1.compute.amazonaws.com (3.65.201.207): icmp_seq=5 ttl=63 time=0.351 ms
#
# --- litespeed.antoniszczepanik.com ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4073ms
# rtt min/avg/max/mdev = 0.349/0.366/0.413/0.023 ms

# %% [markdown]
# ### Bandwidth - TCP & UDP

# %%
# TODO: Make sure iperf is running on all servers.
# !iperf -c {nginx["ip"]} -p {iperf_port}
# !iperf -u -c {nginx["ip"]} -p {iperf_port} -b 0
# Out:
# Connecting to host 3.69.173.4, port 6969
# [  5] local 172.31.13.42 port 36580 connected to 3.69.173.4 port 6969
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   360 MBytes  3.02 Gbits/sec  328    532 KBytes
# [  5]   1.00-2.00   sec   378 MBytes  3.17 Gbits/sec  237    301 KBytes
# [  5]   2.00-3.00   sec   398 MBytes  3.33 Gbits/sec  211    433 KBytes
# [  5]   3.00-4.00   sec   439 MBytes  3.68 Gbits/sec  389    542 KBytes
# [  5]   4.00-5.00   sec   488 MBytes  4.09 Gbits/sec  343    400 KBytes
# [  5]   5.00-6.00   sec   460 MBytes  3.86 Gbits/sec  287    580 KBytes
# [  5]   6.00-7.00   sec   412 MBytes  3.46 Gbits/sec  366    673 KBytes
# [  5]   7.00-8.00   sec   512 MBytes  4.30 Gbits/sec  351    550 KBytes
# [  5]   8.00-9.00   sec   511 MBytes  4.29 Gbits/sec  590    375 KBytes
# [  5]   9.00-10.00  sec   455 MBytes  3.82 Gbits/sec  360    481 KBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  4.31 GBytes  3.70 Gbits/sec  3462             sender
# [  5]   0.00-10.00  sec  4.31 GBytes  3.70 Gbits/sec                  receiver
#
# iperf Done.
# Connecting to host 3.69.173.4, port 6969
# [  5] local 172.31.13.42 port 52962 connected to 3.69.173.4 port 6969
# [ ID] Interval           Transfer     Bitrate         Total Datagrams
# [  5]   0.00-1.00   sec   577 MBytes  4.84 Gbits/sec  417620
# [  5]   1.00-2.00   sec   577 MBytes  4.84 Gbits/sec  417570
# [  5]   2.00-3.00   sec   577 MBytes  4.84 Gbits/sec  417720
# [  5]   3.00-4.00   sec   577 MBytes  4.84 Gbits/sec  417790
# [  5]   4.00-5.00   sec   577 MBytes  4.84 Gbits/sec  417550
# [  5]   5.00-6.00   sec   577 MBytes  4.84 Gbits/sec  417780
# [  5]   6.00-7.00   sec   576 MBytes  4.83 Gbits/sec  417090
# [  5]   7.00-8.00   sec   576 MBytes  4.83 Gbits/sec  416910
# [  5]   8.00-9.00   sec   576 MBytes  4.83 Gbits/sec  417270
# [  5]   9.00-10.00  sec   577 MBytes  4.84 Gbits/sec  417770
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Jitter    Lost/Total Datagrams
# [  5]   0.00-10.00  sec  5.63 GBytes  4.84 Gbits/sec  0.000 ms  0/4175070 (0%)  sender
# [  5]   0.00-10.00  sec  3.12 GBytes  2.68 Gbits/sec  0.003 ms  1857273/4169198 (45%)  receiver
#
# iperf Done.

# %% [markdown]
# ### Measuring QUIC performance

# %% [markdown]
# #### h2 load output parsing

# %%
def get_throughput(res):
    fin_line = [l for l in res if l.startswith("finished in ")][0]
    return float(fin_line.split(" ")[-1][:-4])

def get_rps(res):
    fin_line = [l for l in res if l.startswith("finished in ")][0]
    return float(fin_line.split(" ")[3])

def get_success_pct(res):
    req_line = [l for l in res if l.startswith("requests:")][0]
    items = req_line.split(" ")
    return float(items[7])/float(items[1])

# %% [markdown]
# #### Bulk Throughput
#
# Get throughput measurment from the client.

# %%
data_tp = {
    "server": [],
    "throughput": [],
    "protocol": [],
}

for server in servers:
    for protocol in ("h2", "h3",):
        print(f"bulk throughput test {protocol} - {server['name']}")
        # Request the file first, just to warm up caches.
        _ = !h2load -n1 -c1 --npn-list={protocol} https://{server['ip']}/1g.txt
        for i in range(20):
            res = !h2load -n1 -c1 --npn-list={protocol} https://{server['ip']}/1g.txt
            data_tp['server'].append(server['name'])
            data_tp['throughput'].append(get_throughput(res))
            data_tp['protocol'].append(protocol)
            print(f"{get_throughput(res)} MB/s (succ: {get_success_pct(res)})")
# Out:
# bulk throughput test h2 - nginx
# 559.98 MB/s (succ: 1.0)
# 482.55 MB/s (succ: 1.0)
# 532.33 MB/s (succ: 1.0)
# 547.69 MB/s (succ: 1.0)
# 464.95 MB/s (succ: 1.0)
# 548.6 MB/s (succ: 1.0)
# 409.47 MB/s (succ: 1.0)
# 552.58 MB/s (succ: 1.0)
# 537.14 MB/s (succ: 1.0)
# 509.1 MB/s (succ: 1.0)
# 561.3 MB/s (succ: 1.0)
# 454.83 MB/s (succ: 1.0)
# 543.93 MB/s (succ: 1.0)
# 541.55 MB/s (succ: 1.0)
# 290.84 MB/s (succ: 1.0)
# 452.06 MB/s (succ: 1.0)
# 524.38 MB/s (succ: 1.0)
# 522.94 MB/s (succ: 1.0)
# 528.83 MB/s (succ: 1.0)
# 429.65 MB/s (succ: 1.0)
# bulk throughput test h3 - nginx
# 152.24 MB/s (succ: 1.0)
# 153.66 MB/s (succ: 1.0)
# 148.6 MB/s (succ: 1.0)
# 150.52 MB/s (succ: 1.0)
# 145.3 MB/s (succ: 1.0)
# 146.37 MB/s (succ: 1.0)
# 159.89 MB/s (succ: 1.0)
# 165.56 MB/s (succ: 1.0)
# 157.87 MB/s (succ: 1.0)
# 155.24 MB/s (succ: 1.0)
# 135.85 MB/s (succ: 1.0)
# 154.52 MB/s (succ: 1.0)
# 163.39 MB/s (succ: 1.0)
# 153.02 MB/s (succ: 1.0)
# 162.83 MB/s (succ: 1.0)
# 162.68 MB/s (succ: 1.0)
# 150.84 MB/s (succ: 1.0)
# 145.77 MB/s (succ: 1.0)
# 162.14 MB/s (succ: 1.0)
# 165.23 MB/s (succ: 1.0)
# bulk throughput test h2 - h2o
# 456.09 MB/s (succ: 1.0)
# 506.78 MB/s (succ: 1.0)
# 474.88 MB/s (succ: 1.0)
# 484.27 MB/s (succ: 1.0)
# 465.18 MB/s (succ: 1.0)
# 522.71 MB/s (succ: 1.0)
# 505.38 MB/s (succ: 1.0)
# 490.83 MB/s (succ: 1.0)
# 548.75 MB/s (succ: 1.0)
# 536.68 MB/s (succ: 1.0)
# 506.75 MB/s (succ: 1.0)
# 477.71 MB/s (succ: 1.0)
# 538.18 MB/s (succ: 1.0)
# 483.58 MB/s (succ: 1.0)
# 561.88 MB/s (succ: 1.0)
# 513.19 MB/s (succ: 1.0)
# 388.59 MB/s (succ: 1.0)
# 540.53 MB/s (succ: 1.0)
# 536.59 MB/s (succ: 1.0)
# 460.16 MB/s (succ: 1.0)
# bulk throughput test h3 - h2o
# 288.69 MB/s (succ: 1.0)
# 277.4 MB/s (succ: 1.0)
# 265.12 MB/s (succ: 1.0)
# 252.16 MB/s (succ: 1.0)
# 282.32 MB/s (succ: 1.0)
# 223.05 MB/s (succ: 1.0)
# 267.81 MB/s (succ: 1.0)
# 255.88 MB/s (succ: 1.0)
# 256.06 MB/s (succ: 1.0)
# 270.74 MB/s (succ: 1.0)
# 241.93 MB/s (succ: 1.0)
# 234.82 MB/s (succ: 1.0)
# 213.8 MB/s (succ: 1.0)
# 251.83 MB/s (succ: 1.0)
# 228.48 MB/s (succ: 1.0)
# 280.87 MB/s (succ: 1.0)
# 266.77 MB/s (succ: 1.0)
# 263.11 MB/s (succ: 1.0)
# 267.96 MB/s (succ: 1.0)
# 282.86 MB/s (succ: 1.0)
# bulk throughput test h2 - caddy
# 355.56 MB/s (succ: 1.0)
# 287.44 MB/s (succ: 1.0)
# 352.1 MB/s (succ: 1.0)
# 356.62 MB/s (succ: 1.0)
# 287.11 MB/s (succ: 1.0)
# 288.72 MB/s (succ: 1.0)
# 348.99 MB/s (succ: 1.0)
# 284.59 MB/s (succ: 1.0)
# 272.54 MB/s (succ: 1.0)
# 345.33 MB/s (succ: 1.0)
# 343.9 MB/s (succ: 1.0)
# 280.98 MB/s (succ: 1.0)
# 281.92 MB/s (succ: 1.0)
# 347.25 MB/s (succ: 1.0)
# 350.01 MB/s (succ: 1.0)
# 357.17 MB/s (succ: 1.0)
# 356.56 MB/s (succ: 1.0)
# 286.99 MB/s (succ: 1.0)
# 294.65 MB/s (succ: 1.0)
# 356.7 MB/s (succ: 1.0)
# bulk throughput test h3 - caddy
# 143.47 MB/s (succ: 1.0)
# 143.27 MB/s (succ: 1.0)
# 133.77 MB/s (succ: 1.0)
# 142.35 MB/s (succ: 1.0)
# 137.13 MB/s (succ: 1.0)
# 144.77 MB/s (succ: 1.0)
# 146.71 MB/s (succ: 1.0)
# 147.54 MB/s (succ: 1.0)
# 133.98 MB/s (succ: 1.0)
# 136.67 MB/s (succ: 1.0)
# 134.57 MB/s (succ: 1.0)
# 133.03 MB/s (succ: 1.0)
# 131.97 MB/s (succ: 1.0)
# 143.52 MB/s (succ: 1.0)
# 138.1 MB/s (succ: 1.0)
# 133.17 MB/s (succ: 1.0)
# 138.3 MB/s (succ: 1.0)
# 136.57 MB/s (succ: 1.0)
# 137.52 MB/s (succ: 1.0)
# 147.15 MB/s (succ: 1.0)
# bulk throughput test h2 - openlitespeed
# 559.94 MB/s (succ: 1.0)
# 548.36 MB/s (succ: 1.0)
# 561.14 MB/s (succ: 1.0)
# 556.53 MB/s (succ: 1.0)
# 498.8 MB/s (succ: 1.0)
# 524.19 MB/s (succ: 1.0)
# 418.18 MB/s (succ: 1.0)
# 509.06 MB/s (succ: 1.0)
# 559.68 MB/s (succ: 1.0)
# 492.37 MB/s (succ: 1.0)
# 482.85 MB/s (succ: 1.0)
# 551.66 MB/s (succ: 1.0)
# 527.72 MB/s (succ: 1.0)
# 529.31 MB/s (succ: 1.0)
# 549.5 MB/s (succ: 1.0)
# 492.19 MB/s (succ: 1.0)
# 532.27 MB/s (succ: 1.0)
# 560.61 MB/s (succ: 1.0)
# 553.16 MB/s (succ: 1.0)
# 524.48 MB/s (succ: 1.0)
# bulk throughput test h3 - openlitespeed
# 282.68 MB/s (succ: 1.0)
# 299.9 MB/s (succ: 1.0)
# 326.04 MB/s (succ: 1.0)
# 325.85 MB/s (succ: 1.0)
# 321.82 MB/s (succ: 1.0)
# 321.07 MB/s (succ: 1.0)
# 290.37 MB/s (succ: 1.0)
# 308.67 MB/s (succ: 1.0)
# 312.95 MB/s (succ: 1.0)
# 313.42 MB/s (succ: 1.0)
# 299.84 MB/s (succ: 1.0)
# 330.07 MB/s (succ: 1.0)
# 311.41 MB/s (succ: 1.0)
# 266.56 MB/s (succ: 1.0)
# 279.15 MB/s (succ: 1.0)
# 313.15 MB/s (succ: 1.0)
# 289.94 MB/s (succ: 1.0)
# 311.57 MB/s (succ: 1.0)
# 276.79 MB/s (succ: 1.0)
# 318.62 MB/s (succ: 1.0)

# %%
# Out:
#             server  throughput protocol
# 0            nginx      559.98       h2
# 1            nginx      482.55       h2
# 2            nginx      532.33       h2
# 3            nginx      547.69       h2
# 4            nginx      464.95       h2
# ..             ...         ...      ...
# 155  openlitespeed      313.15       h3
# 156  openlitespeed      289.94       h3
# 157  openlitespeed      311.57       h3
# 158  openlitespeed      276.79       h3
# 159  openlitespeed      318.62       h3
#
# [160 rows x 3 columns]

# %%
df_tp = pd.DataFrame(data_tp)

sns.set(rc={'figure.figsize':(20,10)})

# ax = sns.boxplot(x="server", y="throughput", hue="protocol", data=df_tp, palette="Set3")

g = sns.catplot(x="protocol", y="throughput",hue="protocol", col="server",data=df_tp, kind="box",height=8, aspect=.4);

# %%
data_rps = {
    "server": [],
    "rps": [],
    "protocol": [],
}

for server in servers:
    for protocol in ("h2", "h3"):
        print(f"rps test {protocol} - {server['name']}")
        for i in range(10):
            res = !h2load -n100000 -t $(nproc) -c 50 -m 100 --npn-list={protocol} https://{server['ip']}/index.html
            data_rps['server'].append(server['name'])
            data_rps['rps'].append(get_rps(res))
            data_rps['protocol'].append(protocol)
            print(f"{get_rps(res)} req/s (succ: {get_success_pct(res):.3f})")
# Out:
# rps test h2 - nginx
# 45704.19 req/s (succ: 1.000)
# 47069.61 req/s (succ: 1.000)
# 48975.19 req/s (succ: 1.000)
# 49295.49 req/s (succ: 1.000)
# 48123.31 req/s (succ: 1.000)
# 48592.0 req/s (succ: 1.000)
# 48944.18 req/s (succ: 1.000)
# 48435.51 req/s (succ: 1.000)
# 48746.2 req/s (succ: 1.000)
# 49927.88 req/s (succ: 1.000)
# rps test h3 - nginx
# 75489.3 req/s (succ: 1.000)
# 75056.2 req/s (succ: 1.000)
# 74535.2 req/s (succ: 1.000)
# 73083.98 req/s (succ: 1.000)
# 74052.3 req/s (succ: 1.000)
# 74625.14 req/s (succ: 1.000)
# 74305.36 req/s (succ: 1.000)
# 73762.63 req/s (succ: 1.000)
# 72580.37 req/s (succ: 1.000)
# 76424.9 req/s (succ: 1.000)
# rps test h2 - h2o
# 114606.74 req/s (succ: 1.000)
# 191797.58 req/s (succ: 1.000)
# 213744.64 req/s (succ: 1.000)
# 219274.2 req/s (succ: 1.000)
# 219148.78 req/s (succ: 1.000)
# 222685.9 req/s (succ: 1.000)
# 217448.5 req/s (succ: 1.000)
# 213003.43 req/s (succ: 1.000)
# 219248.72 req/s (succ: 1.000)
# 216362.17 req/s (succ: 1.000)
# rps test h3 - h2o
# 131516.82 req/s (succ: 1.000)
# 138625.5 req/s (succ: 1.000)
# 131869.06 req/s (succ: 1.000)
# 135666.62 req/s (succ: 1.000)
# 132954.5 req/s (succ: 1.000)
# 138230.37 req/s (succ: 1.000)
# 133656.6 req/s (succ: 1.000)
# 132840.76 req/s (succ: 1.000)
# 133114.14 req/s (succ: 1.000)
# 136414.11 req/s (succ: 1.000)
# rps test h2 - caddy
# 9781.66 req/s (succ: 1.000)
# 10098.36 req/s (succ: 1.000)
# 9981.21 req/s (succ: 1.000)
# 10012.17 req/s (succ: 1.000)
# 9974.86 req/s (succ: 1.000)
# 10011.24 req/s (succ: 1.000)
# 9994.08 req/s (succ: 1.000)
# 9967.63 req/s (succ: 1.000)
# 10002.22 req/s (succ: 1.000)
# 9532.02 req/s (succ: 1.000)
# rps test h3 - caddy
# 11381.98 req/s (succ: 1.000)
# 11474.7 req/s (succ: 1.000)
# 11296.03 req/s (succ: 1.000)
# 11454.24 req/s (succ: 1.000)
# 11247.55 req/s (succ: 1.000)
# 11249.95 req/s (succ: 1.000)
# 11313.11 req/s (succ: 1.000)
# 11250.37 req/s (succ: 1.000)
# 11295.3 req/s (succ: 1.000)
# 11402.26 req/s (succ: 1.000)
# rps test h2 - openlitespeed
# 129895.1 req/s (succ: 1.000)
# 140799.26 req/s (succ: 1.000)
# 138781.14 req/s (succ: 1.000)
# 142580.94 req/s (succ: 1.000)
# 140457.33 req/s (succ: 1.000)
# 138383.02 req/s (succ: 1.000)
# 140252.65 req/s (succ: 1.000)
# 140800.45 req/s (succ: 1.000)
# 141058.65 req/s (succ: 1.000)
# 138427.27 req/s (succ: 1.000)
# rps test h3 - openlitespeed
# 64628.46 req/s (succ: 1.000)
# 64767.17 req/s (succ: 1.000)
# 59938.38 req/s (succ: 1.000)
# 61677.19 req/s (succ: 1.000)
# 65623.95 req/s (succ: 1.000)
# 64872.59 req/s (succ: 1.000)
# 65203.71 req/s (succ: 1.000)
# 64845.12 req/s (succ: 1.000)
# 66522.36 req/s (succ: 1.000)
# 66630.33 req/s (succ: 1.000)

# %%
df_rps= pd.DataFrame(data_rps)
sns.set(rc={'figure.figsize':(20,10)})
# ax = sns.boxplot(x="server", y="throughput", hue="protocol", data=df_tp, palette="Set3")
g = sns.catplot(x="protocol", y="rps",hue="protocol", col="server",data=df_rps, kind="box",height=8, aspect=.4);

# %%
# RPS with single connection (vary multiplexing level)

# %%
data_rps = {
    "server": [],
    "rps": [],
    "protocol": [],
}

for server in servers:
    for protocol in ("h2", "h3"):
        print(f"rps test {protocol} - {server['name']}")
        for i in range(10):
            res = !h2load -n100000 -t $(nproc) -c $(nproc) -m 100 --npn-list={protocol} https://{server['ip']}/index.html
            data_rps['server'].append(server['name'])
            data_rps['rps'].append(get_rps(res))
            data_rps['protocol'].append(protocol)
            print(f"{get_rps(res)} req/s (succ: {get_success_pct(res):.3f})")
# Out:
# rps test h2 - nginx
# 36608.7 req/s (succ: 1.000)
# 50867.44 req/s (succ: 1.000)
# 36801.16 req/s (succ: 1.000)
# 50348.16 req/s (succ: 1.000)
# 49503.63 req/s (succ: 1.000)
# 50327.0 req/s (succ: 1.000)
# 50095.46 req/s (succ: 1.000)
# 39849.34 req/s (succ: 1.000)
# 39483.1 req/s (succ: 1.000)
# 47323.73 req/s (succ: 1.000)
# rps test h3 - nginx
# 76520.52 req/s (succ: 1.000)
# 76747.91 req/s (succ: 1.000)
# 78814.57 req/s (succ: 1.000)
# 78468.36 req/s (succ: 1.000)
# 78714.25 req/s (succ: 1.000)
# 77212.33 req/s (succ: 1.000)
# 77102.67 req/s (succ: 1.000)
# 78746.61 req/s (succ: 1.000)
# 74797.45 req/s (succ: 1.000)
# 76410.77 req/s (succ: 1.000)
# rps test h2 - h2o
# 187003.27 req/s (succ: 1.000)
# 173920.0 req/s (succ: 1.000)
# 207753.79 req/s (succ: 1.000)
# 239831.73 req/s (succ: 1.000)
# 236131.41 req/s (succ: 1.000)
# 212409.83 req/s (succ: 1.000)
# 240792.11 req/s (succ: 1.000)
# 208428.86 req/s (succ: 1.000)
# 208197.57 req/s (succ: 1.000)
# 207250.45 req/s (succ: 1.000)
# rps test h3 - h2o
# 121543.46 req/s (succ: 1.000)
# 121724.99 req/s (succ: 1.000)
# 105929.06 req/s (succ: 1.000)
# 115323.76 req/s (succ: 1.000)
# 119723.06 req/s (succ: 1.000)
# 116529.88 req/s (succ: 1.000)
# 105596.73 req/s (succ: 1.000)
# 117990.06 req/s (succ: 1.000)
# 122000.61 req/s (succ: 1.000)
# 119268.27 req/s (succ: 1.000)
# rps test h2 - caddy
# 9680.41 req/s (succ: 1.000)
# 10165.46 req/s (succ: 1.000)
# 10034.06 req/s (succ: 1.000)
# 10217.8 req/s (succ: 1.000)
# ^C
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [52], in <cell line: 7>()
#      11 res = get_ipython().getoutput("h2load -n100000 -t $(nproc) -c $(nproc) -m 100 --npn-list={protocol} https://{server['ip']}/index.html")
#      12 data_rps['server'].append(server['name'])
# ---> 13 data_rps['rps'].append(get_rps(res))
#      14 data_rps['protocol'].append(protocol)
#      15 print(f"{get_rps(res)} req/s (succ: {get_success_pct(res):.3f})")
#
# Input In [3], in get_rps(res)
#       5 def get_rps(res):
# ----> 6     fin_line = [l for l in res if l.startswith("finished in ")][0]
#       7     return float(fin_line.split(" ")[3])
#
# IndexError: list index out of range

# %%
for i in range(1, 101):
    res = !h2load -D1s -t $(nproc) -c $(nproc) -m {i} --npn-list=h2 https://{ls['ip']}/index.html
    print(f"{get_rps(res)} req/s (succ: {get_success_pct(res):.3f})")
# Out:
# 5009.0 req/s (succ: 1.000)
# 10682.0 req/s (succ: 1.000)
# 17400.0 req/s (succ: 1.000)
# 20164.0 req/s (succ: 1.000)
# 24180.0 req/s (succ: 1.000)
# 30366.0 req/s (succ: 1.000)
# 33845.0 req/s (succ: 1.000)
# 40440.0 req/s (succ: 1.000)
# 41049.0 req/s (succ: 1.000)
# 51360.0 req/s (succ: 1.000)
# 47443.0 req/s (succ: 1.000)
# 49944.0 req/s (succ: 1.000)
# 56160.0 req/s (succ: 1.000)
# 59626.0 req/s (succ: 1.000)
# 62760.0 req/s (succ: 1.000)
# 64224.0 req/s (succ: 1.000)
# 67167.0 req/s (succ: 1.000)
# 72900.0 req/s (succ: 1.000)
# 76570.0 req/s (succ: 1.000)
# 79760.0 req/s (succ: 1.000)
# 78372.0 req/s (succ: 1.000)
# 70092.0 req/s (succ: 1.000)
# 80477.0 req/s (succ: 1.000)
# 84120.0 req/s (succ: 1.000)
# 81550.0 req/s (succ: 1.000)
# 88556.0 req/s (succ: 1.000)
# 87075.0 req/s (succ: 1.000)
# 88172.0 req/s (succ: 1.000)
# 95990.0 req/s (succ: 1.000)
# 90630.0 req/s (succ: 1.000)
# 92132.0 req/s (succ: 1.000)
# 83776.0 req/s (succ: 1.000)
# 93126.0 req/s (succ: 1.000)
# 95370.0 req/s (succ: 1.000)
# 87430.0 req/s (succ: 1.000)
# 90000.0 req/s (succ: 1.000)
# 99900.0 req/s (succ: 1.000)
# 106856.0 req/s (succ: 1.000)
# 106509.0 req/s (succ: 1.000)
# 102760.0 req/s (succ: 1.000)
# 109224.0 req/s (succ: 1.000)
# 113736.0 req/s (succ: 1.000)
# 115455.0 req/s (succ: 1.000)
# 116116.0 req/s (succ: 1.000)
# 106875.0 req/s (succ: 1.000)
# 120428.0 req/s (succ: 1.000)
# 116607.0 req/s (succ: 1.000)
# 115728.0 req/s (succ: 1.000)
# 123921.0 req/s (succ: 1.000)
# 124000.0 req/s (succ: 1.000)
# 112098.0 req/s (succ: 1.000)
# 127348.0 req/s (succ: 1.000)
# 131281.0 req/s (succ: 1.000)
# 128196.0 req/s (succ: 1.000)
# 122595.0 req/s (succ: 1.000)
# 129696.0 req/s (succ: 1.000)
# 126540.0 req/s (succ: 1.000)
# 130964.0 req/s (succ: 1.000)
# 118708.0 req/s (succ: 1.000)
# 122400.0 req/s (succ: 1.000)
# 120109.0 req/s (succ: 1.000)
# 122388.0 req/s (succ: 1.000)
# 129276.0 req/s (succ: 1.000)
# 132288.0 req/s (succ: 1.000)
# 136760.0 req/s (succ: 1.000)
# 133782.0 req/s (succ: 1.000)
# 121806.0 req/s (succ: 1.000)
# 123012.0 req/s (succ: 1.000)
# 134274.0 req/s (succ: 1.000)
# 137550.0 req/s (succ: 1.000)
# 122262.0 req/s (succ: 1.000)
# 139464.0 req/s (succ: 1.000)
# 124830.0 req/s (succ: 1.000)
# 126910.0 req/s (succ: 1.000)
# 125100.0 req/s (succ: 1.000)
# 130340.0 req/s (succ: 1.000)
# 137291.0 req/s (succ: 1.000)
# 136188.0 req/s (succ: 1.000)
# 121423.0 req/s (succ: 1.000)
# 124560.0 req/s (succ: 1.000)
# 109026.0 req/s (succ: 1.000)
# 120786.0 req/s (succ: 1.000)
# 140270.0 req/s (succ: 1.000)
# 129948.0 req/s (succ: 1.000)
# 125630.0 req/s (succ: 1.000)
# 127452.0 req/s (succ: 1.000)
# 140853.0 req/s (succ: 1.000)
# 128920.0 req/s (succ: 1.000)
# 138840.0 req/s (succ: 1.000)
# 125820.0 req/s (succ: 1.000)
# 127946.0 req/s (succ: 1.000)
# 139104.0 req/s (succ: 1.000)
# 128154.0 req/s (succ: 1.000)
# 138744.0 req/s (succ: 1.000)
# 123880.0 req/s (succ: 1.000)
# 144192.0 req/s (succ: 1.000)
# 137934.0 req/s (succ: 1.000)
# 142492.0 req/s (succ: 1.000)
# 138006.0 req/s (succ: 1.000)
# 141800.0 req/s (succ: 1.000)
